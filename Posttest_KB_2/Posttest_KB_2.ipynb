# %% [markdown]
#  1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %% [markdown]
# Menggunakan pandas untuk menjalankan program

# %%
import pandas as pd

# %%
df=pd.read_csv("tornados.csv")

# %%
pd.DataFrame(df)
# Out:
#            om    yr  mo  dy        date      time               tz
# 0         192  1950  10   1  1950-10-01  21:00:00  America/Chicago  \
# 1         193  1950  10   9  1950-10-09  02:15:00  America/Chicago
# 2         195  1950  11  20  1950-11-20  02:20:00  America/Chicago
# 3         196  1950  11  20  1950-11-20  04:00:00  America/Chicago
# 4         197  1950  11  20  1950-11-20  07:30:00  America/Chicago
# ...       ...   ...  ..  ..         ...       ...              ...
# 68688  621922  2022   9  28  2022-09-28  13:32:00  America/Chicago
# 68689  621923  2022   9  30  2022-09-30  10:25:00  America/Chicago
# 68690  621924  2022   9  30  2022-09-30  13:22:00  America/Chicago
# 68691  621900  2022   9   4  2022-09-04  15:44:00  America/Chicago
# 68692  621901  2022   9   9  2022-09-09  23:21:00  America/Chicago
#
#                datetime_utc  st  stf  ...      elon    len  wid  ns  sn   f1
# 0      1950-10-02T03:00:00Z  OK   40  ... -102.3000  15.80   10   1   1   25  \
# ...

# %%
df.describe()
# Out:
#                   om            yr            mo            dy           stf
# count   68693.000000  68693.000000  68693.000000  68693.000000  68693.000000  \
# mean   113201.815542   1991.854061      5.968541     15.930881     29.220255
# std    226621.993899     19.565158      2.444656      8.750070     15.013273
# min         1.000000   1950.000000      1.000000      1.000000      1.000000
# 25%       285.000000   1976.000000      4.000000      8.000000     18.000000
# 50%       588.000000   1995.000000      6.000000     16.000000     28.000000
# 75%      1118.000000   2008.000000      7.000000     24.000000     42.000000
# max    622080.000000   2022.000000     12.000000     31.000000     78.000000
#
#                 mag           inj          fat          loss          slat
# count  67937.000000  68693.000000  68693.00000  4.152300e+04  68693.000000  \
# mean       0.778721      1.418689      0.08931  2.020898e+06     37.129386
# ...

# %% [markdown]
# 2.Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
AtributAngka = df.select_dtypes(include=['int64', 'float64'])
AtributAngka.head(10)
# Out:
#     om    yr  mo  dy  stf  mag  inj  fat       loss   slat  ...   elat
# 0  192  1950  10   1   40  1.0    0    0    50000.0  36.73  ...  36.88  \
# 1  193  1950  10   9   37  3.0    3    0   500000.0  34.17  ...   0.00
# 2  195  1950  11  20   21  2.0    0    0   500000.0  37.37  ...   0.00
# 3  196  1950  11  20   21  1.0    0    0   500000.0  38.20  ...   0.00
# 4  197  1950  11  20   28  1.0    3    0    50000.0  32.42  ...   0.00
# 5  194  1950  11   4   42  3.0    1    0   500000.0  40.20  ...  40.40
# 6  198  1950  12   2   17  2.0    3    1    50000.0  38.97  ...  39.07
# 7  199  1950  12   2   17  3.0   25    2  5000000.0  38.75  ...  38.90
# 8  200  1950  12   2    5  3.0    0    0       50.0  36.12  ...  36.18
# 9  201  1950  12   2   17  1.0    0    0    50000.0  38.17  ...  38.22
#
#      elon   len  wid  ns  sn   f1   f2  f3  f4
# 0 -102.30  15.8   10   1   1   25    0   0   0
# 1    0.00   2.0  880   1   1   47    0   0   0
# ...

# %% [markdown]
# 3.Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
info = {}
info['Menampilkan record'] = len(df)
info['Menampilkan Jumlah Atrribute'] = df.shape[1]
info['Menampilkan  Nama Atributte'] = df.columns
info['Menampilkan Jumlah Atrribute bertipe angka'] = df.select_dtypes(include=['int', 'float']).shape[1]
pd.DataFrame.from_dict(info)
# Out:
#     Menampilkan record  Menampilkan Jumlah Atrribute
# 0                68693                            27  \
# 1                68693                            27
# 2                68693                            27
# 3                68693                            27
# 4                68693                            27
# 5                68693                            27
# 6                68693                            27
# 7                68693                            27
# 8                68693                            27
# 9                68693                            27
# 10               68693                            27
# 11               68693                            27
# 12               68693                            27
# 13               68693                            27
# 14               68693                            27
# 15               68693                            27
# 16               68693                            27
# ...

# %% [markdown]
# 4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.

# %% [markdown]
# Menggunakan loc

# %%
df.loc[139:,'time':]
# Out:
#            time               tz          datetime_utc  st  stf  mag  inj
# 139    01:00:00  America/Chicago  1950-06-15T06:00:00Z  MO   29  1.0    0  \
# 140    16:42:00  America/Chicago  1950-06-15T21:42:00Z  MN   27  2.0    4
# 141    20:00:00  America/Chicago  1950-06-16T01:00:00Z  IA   19  3.0    5
# 142    15:30:00  America/Chicago  1950-06-16T20:30:00Z  KS   20  1.0    0
# 143    20:40:00  America/Chicago  1950-06-20T01:40:00Z  TX   48  0.0    0
# ...         ...              ...                   ...  ..  ...  ...  ...
# 68688  13:32:00  America/Chicago  2022-09-28T18:32:00Z  FL   12  0.0    0
# 68689  10:25:00  America/Chicago  2022-09-30T15:25:00Z  NC   37  0.0    0
# 68690  13:22:00  America/Chicago  2022-09-30T18:22:00Z  NC   37  NaN    0
# 68691  15:44:00  America/Chicago  2022-09-04T20:44:00Z  OH   39  0.0    0
# 68692  23:21:00  America/Chicago  2022-09-10T04:21:00Z  SC   45  0.0    0
#
#        fat     loss     slat  ...      elon    len  wid  ns  sn   f1  f2  f3
# ...

# %% [markdown]
# Menggunakan iloc

# %%
df.iloc[139:,4:]
# Out:
#              date      time               tz          datetime_utc  st  stf
# 139    1950-06-15  01:00:00  America/Chicago  1950-06-15T06:00:00Z  MO   29  \
# 140    1950-06-15  16:42:00  America/Chicago  1950-06-15T21:42:00Z  MN   27
# 141    1950-06-15  20:00:00  America/Chicago  1950-06-16T01:00:00Z  IA   19
# 142    1950-06-16  15:30:00  America/Chicago  1950-06-16T20:30:00Z  KS   20
# 143    1950-06-19  20:40:00  America/Chicago  1950-06-20T01:40:00Z  TX   48
# ...           ...       ...              ...                   ...  ..  ...
# 68688  2022-09-28  13:32:00  America/Chicago  2022-09-28T18:32:00Z  FL   12
# 68689  2022-09-30  10:25:00  America/Chicago  2022-09-30T15:25:00Z  NC   37
# 68690  2022-09-30  13:22:00  America/Chicago  2022-09-30T18:22:00Z  NC   37
# 68691  2022-09-04  15:44:00  America/Chicago  2022-09-04T20:44:00Z  OH   39
# 68692  2022-09-09  23:21:00  America/Chicago  2022-09-10T04:21:00Z  SC   45
#
# ...

# %% [markdown]
# 5. Tampilkan jumlah nilai dari semua attribute yang bernilai object (contoh : Jenis Kelamin, Agama).

# %%
kolobjek = data.select_dtypes(include='object')
jmlh_kolm_objk = kolobjek.nunique()
pd.DataFrame({'Menampilkan Jumlah Kolom Objek ': jmlh_kolm_objk})
# Out:
#               Menampilkan Jumlah Kolom Objek
# date                                    12458
# time                                     1438
# tz                                          3
# datetime_utc                            64866
# st                                         53
